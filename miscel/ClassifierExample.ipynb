# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.random.randn(100,1)+5
y1 = np.random.randn(100,1)+3

x2 = np.random.randn(100,1)+8
y2 = np.random.randn(100,1)+1


plt.plot(x1,y1,'.')
plt.plot(x2,y2,'r.')
